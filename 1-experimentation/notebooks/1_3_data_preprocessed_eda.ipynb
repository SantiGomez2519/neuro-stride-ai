# %% [markdown]
# # 1.3 — Exploratory Data Analysis
#
# EDA on preprocessed and normalized gait-cycle data.
#
# | | |
# |---|---|
# | **Inputs** | Preprocessed normalized cycles from `1_2_data_raw_preprocessing.ipynb` |
# | **Outputs** | (visualization only) |
#
# > **TODO:** Implement after preprocessing pipeline is fully validated.

# %%
import sys
from pathlib import Path

import matplotlib.pyplot as plt
import pandas as pd
import seaborn as sns

PROJECT_ROOT = Path.cwd().resolve().parent.parent
if str(PROJECT_ROOT) not in sys.path:
    sys.path.insert(0, str(PROJECT_ROOT))
if str(PROJECT_ROOT / "shared") not in sys.path:
    sys.path.insert(0, str(PROJECT_ROOT / "shared"))

# %% [markdown]
# ## TODO
#
# - [ ] Load preprocessed normalized cycles
# - [ ] Distribution of gait parameters across subjects
# - [ ] Comparison across cohorts (TD, UCP, BCP)
# - [ ] Correlation analysis of kinematic/kinetic features
# - [ ] Outlier detection at the cycle level
