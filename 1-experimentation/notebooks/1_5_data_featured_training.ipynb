# %% [markdown]
# # 1.5 — Model Training
#
# Train a classification or regression model on gait features.
#
# | | |
# |---|---|
# | **Inputs** | Feature tables from `1_4_data_preprocessed_feature_engineering.ipynb` |
# | **Outputs** | Trained model artifact, model config |
#
# > **TODO:** Implement after feature engineering produces usable feature tables.

# %%
import sys
from pathlib import Path

import pandas as pd

PROJECT_ROOT = Path.cwd().resolve().parent.parent
if str(PROJECT_ROOT) not in sys.path:
    sys.path.insert(0, str(PROJECT_ROOT))
if str(PROJECT_ROOT / "shared") not in sys.path:
    sys.path.insert(0, str(PROJECT_ROOT / "shared"))

# %% [markdown]
# ## TODO
#
# - [ ] Load aggregated feature table
# - [ ] Define train/test split strategy
# - [ ] Train baseline models (e.g., RandomForest, GradientBoosting)
# - [ ] Cross-validate and select best model
# - [ ] Save model artifact and config to `shared/models/`
