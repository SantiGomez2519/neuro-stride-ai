# %% [markdown]
# # 1.6 — Model Evaluation on New Data
#
# Evaluate the trained model on held-out or new trial data.
#
# | | |
# |---|---|
# | **Inputs** | Trained model from `1_5`, new trial data |
# | **Outputs** | Evaluation metrics, prediction comparisons |
#
# > **TODO:** Implement after training step produces a model artifact.

# %%
import sys
from pathlib import Path

import pandas as pd

PROJECT_ROOT = Path.cwd().resolve().parent.parent
if str(PROJECT_ROOT) not in sys.path:
    sys.path.insert(0, str(PROJECT_ROOT))
if str(PROJECT_ROOT / "shared") not in sys.path:
    sys.path.insert(0, str(PROJECT_ROOT / "shared"))

# %% [markdown]
# ## TODO
#
# - [ ] Load trained model from `shared/models/`
# - [ ] Process new trial data through the preprocessing pipeline
# - [ ] Extract features from new data
# - [ ] Generate predictions
# - [ ] Compute and report evaluation metrics
# - [ ] Visualize prediction vs ground truth
