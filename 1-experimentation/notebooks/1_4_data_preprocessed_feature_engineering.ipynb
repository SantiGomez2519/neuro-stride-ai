# %% [markdown]
# # 1.4 — Feature Engineering
#
# Extract biomechanical features from preprocessed gait cycles.
#
# | | |
# |---|---|
# | **Inputs** | Normalized gait cycles, cleaned analog, contact events from `1_2` |
# | **Outputs** | Cycle-level and aggregated feature tables |
#
# > **TODO:** Implement after preprocessing pipeline produces artifacts that can be reused here.

# %%
import sys
from pathlib import Path

import pandas as pd

PROJECT_ROOT = Path.cwd().resolve().parent
if str(PROJECT_ROOT) not in sys.path:
    sys.path.insert(0, str(PROJECT_ROOT))

from gait_processing.features import (
    compute_cycle_features,
    aggregate_features,
    pairwise_trial_symmetry,
)

# %% [markdown]
# ## TODO
#
# - [ ] Load preprocessed kin, analog, contacts, and cycles
# - [ ] Run `compute_cycle_features()` per trial
# - [ ] Aggregate across cycles with `aggregate_features()`
# - [ ] Compute left-right symmetry with `pairwise_trial_symmetry()`
# - [ ] Save feature tables to `data/featured/`
